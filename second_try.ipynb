# %%
from groq import Groq
from dotenv import load_dotenv
import os
import pdfplumber

# %%
load_dotenv()
client = Groq(api_key=os.getenv("GROQ_API_KEY"))
print("Groq client ready")
# Out:
# Groq client ready

# %%
def call_llm(text):
    response = client.chat.completions.create(
        model="llama-3.1-8b-instant",  # current working model
        messages=[{"role": "user", "content": text}],
        temperature=0
    )
    return response.choices[0].message.content

# %%
def load_contract(path):
    ext = os.path.splitext(path)[1].lower()

    if ext == ".txt":
        with open(path, "r", encoding="utf-8") as f:
            return f.read()

    elif ext == ".pdf":
        text = []
        with pdfplumber.open(path) as pdf:
            for page in pdf.pages:
                page_text = page.extract_text()
                if page_text:
                    text.append(page_text)
        return "\n".join(text)

    else:
        raise ValueError("Unsupported file type")

# %%
def chunk_text(text, chunk_size=8000, overlap=500):
    chunks = []
    start = 0

    while start < len(text):
        end = start + chunk_size
        chunks.append(text[start:end])
        start = end - overlap

    return chunks

# %%
def summarize_chunk(chunk):
    prompt = f"""
Summarize the following contract text into concise factual notes.
- Extract clauses, obligations, payments, timelines, responsibilities
- Do NOT analyze
- Do NOT format
- Keep it short and factual

Text:
{chunk}
"""
    return call_llm(prompt)

# %%
def batch_reduce(summaries, batch_size=5):
    reduced = []

    for i in range(0, len(summaries), batch_size):
        batch = summaries[i:i+batch_size]
        batch_text = "\n\n".join(batch)

        prompt = f"""
Combine the following notes into a concise unified summary.
Do not lose important details.

Notes:
{batch_text}
"""
        reduced.append(call_llm(prompt))

    return reduced

# %%
REVIEW_SECTIONS = [
    "Scope",
    "Duration",
    "Deliverables",
    "Location / Geographical Scope",
    "Timelines",
    "Technical Architecture",
    "Scope Assumptions and Exclusions",
    "Service Level Agreements (SLAs)",
    "Project Structure, Roles and Responsibilities",
    "Handling Changes to Baseline",
    "Commercial Model",
    "Billing Model",
    "Overhead Expenses",
    "Incentives / Disincentives",
    "Procurement and Licensing Model",
    "Operations Model",
    "Acceptance Criteria",
    "Performance Criteria",
    "Discretionary Hours / Development Effort",
    "Minimum Skill Set",
    "Resource Deployment / Replacement Guidelines",
    "Subcontracting / Consortium Guidelines",
    "Handholding Support (Post Go-Live)",
    "Ongoing Operations Support",
    "Technical SOPs and Training to Ops Team",
    "Training and Awareness of End Users",
    "Intellectual Property and Source Code Ownership",
    "Requirements / Support from Client",
    "Governance and Reporting",
    "Contract Exit Mechanism",
    "Payment Terms",
    "Non-Functional Requirements"
]

# %%
def generate_contract_review(notes):
    sections = "\n".join(
        f"{i+1}. {section}"
        for i, section in enumerate(REVIEW_SECTIONS)
    )

    prompt = f"""
You are a contract review assistant.

Generate a contract review strictly following internal PMO review style.

Rules:
- Follow the exact section order.
- For EACH section include:
  Status: Covered / Partially Covered / Not Covered / NA
  Impact: Low / Medium / High / NA
  Key Points: bullet points
  Remarks: only if applicable
- If information is missing, write "Not specified in the contract".
- Do NOT provide legal advice.

Sections:
{sections}

Contract notes:
{notes}
"""
    return call_llm(prompt)

# %%
# 1. Load contract
contract_text = load_contract("contract.pdf")
print("Contract loaded:", len(contract_text), "characters")
# Out:
# Contract loaded: 17691 characters

# %%
# 2. Chunk
chunks = chunk_text(contract_text)
print("Chunks:", len(chunks))
# Out:
# Chunks: 3

# %%
# 3. FIRST PASS (compress chunks)
chunk_summaries = [summarize_chunk(chunk) for chunk in chunks]
print("Chunk summaries done")
# Out:
# Chunk summaries done

# %%
# 4. REDUCTION PASSES
level_2 = batch_reduce(chunk_summaries)
level_3 = batch_reduce(level_2)

# %%
combined_notes = "\n\n".join(level_3)
print("Final notes size:", len(combined_notes))
# Out:
# Final notes size: 2736

# %%
# 5. FINAL REVIEW
final_review = generate_contract_review(combined_notes)
print(final_review)
# Out:
# **Contract Review**
#
# **1. Scope**
#
# - Status: Covered
# - Impact: Medium
# - Key Points:
#   • The parties will engage in the internet-based sale and promotion of tour products.
#   • Party B will provide business consultancy and technical services to Party A and its subsidiaries.
#   • Exclusive cooperation between Party A and Party B.
# - Remarks: The scope of the cooperation is clearly defined, but it may be beneficial to include more specific details about the services to be provided by Party B.
#
# **2. Duration**
#
# - Status: Covered
# - Impact: Medium
# - Key Points:
#   • The term of cooperation commences from the execution date.
#   • The term of cooperation ends on the expiration date of the operation term of Party B.
#   • Termination prior to expiration requires specific circumstances, including bankruptcy, force majeure, or failure to provide services for more than three consecutive years.
# - Remarks: The duration of the cooperation is clearly defined, but it may be beneficial to include a specific end date.
#
# **3. Deliverables**
#
# - Status: Partially Covered
# - Impact: Medium
# - Key Points:
#   • Party B will provide research, development, production, test, operation, and maintenance of relevant technology.
#   • Consultancy services related to sale and promotion of tour products.
#   • Service fee (Service Fee) from Party A or its subsidiaries who have accepted Party B's Services.
# - Remarks: The deliverables are partially covered, but it may be beneficial to include more specific details about the deliverables and the service fee.
#
# **4. Location / Geographical Scope**
#
# - Status: Not Covered
# - Impact: Low
# - Key Points: Not specified in the contract.
# - Remarks: The location and geographical scope of the cooperation are not specified in the contract.
#
# **5. Timelines**
#
# - Status: Partially Covered
# - Impact: Medium
# - Key Points:
#   • The term of cooperation commences from the execution date.
#   • The term of cooperation ends on the expiration date of the operation term of Party B.
#   • Specific circumstances for termination prior to expiration.
# - Remarks: The timelines are partially covered, but it may be beneficial to include more specific details about the milestones and deadlines.
#
# **6. Technical Architecture**
#
# - Status: Not Covered
# - Impact: Medium
# - Key Points: Not specified in the contract.
# - Remarks: The technical architecture of the cooperation is not specified in the contract.
#
# **7. Scope Assumptions and Exclusions**
#
# - Status: Partially Covered
# - Impact: Medium
# - Key Points:
#   • Each party represents and warrants to the other party that it has sufficient capacity for action, power, and authorization to execute and perform the agreement.
#   • Each party is responsible for and holds the other party harmless from any loss, damages, and claim arising out of violation of representations and warranties.
# - Remarks: The scope assumptions and exclusions are partially covered, but it may be beneficial to include more specific details about the assumptions and exclusions.
#
# **8. Service Level Agreements (SLAs)**
#
# - Status: Not Covered
# - Impact: Medium
# - Key Points: Not specified in the contract.
# - Remarks: The service level agreements are not specified in the contract.
#
# **9. Project Structure, Roles and Responsibilities**
#
# - Status: Partially Covered
# - Impact: Medium
# - Key Points:
#   • Each party represents and warrants to the other party that it has sufficient capacity for action, power, and authorization to execute and perform the agreement.
#   • Each party is responsible for and holds the other party harmless from any loss, damages, and claim arising out of violation of representations and warranties.
# - Remarks: The project structure, roles, and responsibilities are partially covered, but it may be beneficial to include more specific details about the roles and responsibilities.
#
# **10. Handling Changes to Baseline**
#
# - Status: Partially Covered
# - Impact: Medium
# - Key Points:
#   • Parties agree to negotiate to decide performance of the agreement in case of force majeure.
#   • Specific circumstances for termination prior to expiration.
# - Remarks: The handling of changes to the baseline is partially covered, but it may be beneficial to include more specific details about the process for handling changes.
#
# **11. Commercial Model**
#
# - Status: Covered
# - Impact: Medium
# - Key Points:
#   • Party B shall have the right to charge a service fee (Service Fee) from Party A or its subsidiaries who have accepted Party B's Services.
# - Remarks: The commercial model is clearly defined, but it may be beneficial to include more specific details about the service fee.
#
# **12. Billing Model**
#
# - Status: Covered
# - Impact: Medium
# - Key Points:
#   • Party B shall have the right to charge a service fee (Service Fee) from Party A or its subsidiaries who have accepted Party B's Services.
# - Remarks: The billing model is clearly defined, but it may be beneficial to include more specific details about the billing process.
#
# **13. Overhead Expenses**
#
# - Status: Not Covered
# - Impact: Low
# - Key Points: Not specified in the contract.
# - Remarks: The overhead expenses are not specified in the contract.
#
# **14. Incentives / Disincentives**
#
# - Status: Not Covered
# - Impact: Low
# - Key Points: Not specified in the contract.
# - Remarks: The incentives and disincentives are not specified in the contract.
#
# **15. Procurement and Licensing Model**
#
# - Status: Not Covered
# - Impact: Medium
# - Key Points: Not specified in the contract.
# - Remarks: The procurement and licensing model is not specified in the contract.
#
# **16. Operations Model**
#
# - Status: Partially Covered
# - Impact: Medium
# - Key Points:
#   • Party B will provide research, development, production, test, operation, and maintenance of relevant technology.
#   • Consultancy services related to sale and promotion of tour products.
# - Remarks: The operations model is partially covered, but it may be beneficial to include more specific details about the operations.
#
# **17. Acceptance Criteria**
#
# - Status: Not Covered
# - Impact: Medium
# - Key Points: Not specified in the contract.
# - Remarks: The acceptance criteria are not specified in the contract.
#
# **18. Performance Criteria**
#
# - Status: Partially Covered
# - Impact: Medium
# - Key Points:
#   • Each party represents and warrants to the other party that it has sufficient capacity for action, power, and authorization to execute and perform the agreement.
#   • Each party is responsible for and holds the other party harmless from any loss, damages, and claim arising out of violation of representations and warranties.
# - Remarks: The performance criteria are partially covered, but it may be beneficial to include more specific details about the performance criteria.
#
# **19. Discretionary Hours / Development Effort**
#
# - Status: Not Covered
# - Impact: Low
# - Key Points: Not specified in the contract.
# - Remarks: The discretionary hours and development effort are not specified in the contract.
#
# **20. Minimum Skill Set**
#
# - Status: Not Covered
# - Impact: Low
# - Key Points: Not specified in the contract.
# - Remarks: The minimum skill set is not specified in the contract.
#
# **21. Resource Deployment / Replacement Guidelines**
#
# - Status: Not Covered
# - Impact: Medium
# - Key Points: Not specified in the contract.
# - Remarks: The resource deployment and replacement guidelines are not specified in the contract.
#
# **22. Subcontracting / Consortium Guidelines**
#
# - Status: Not Covered
# - Impact: Medium
# - Key Points: Not specified in the contract.
# - Remarks: The subcontracting and consortium guidelines are not specified in the contract.
#
# **23. Handholding Support (Post Go-Live)**
#
# - Status: Not Covered
# - Impact: Medium
# - Key Points: Not specified in the contract.
# - Remarks: The handholding support is not specified in the contract.
#
# **24. Ongoing Operations Support**
#
# - Status: Partially Covered
# - Impact: Medium
# - Key Points:
#   • Party B will provide research, development, production, test, operation, and maintenance of relevant technology.
#   • Consultancy services related to sale and promotion of tour products.
# - Remarks: The ongoing operations support is partially covered, but it may be beneficial to include more specific details about the support.
#
# **25. Technical SOPs and Training to Ops Team**
#
# - Status: Not Covered
# - Impact: Medium
# - Key Points: Not specified in the contract.
# - Remarks: The technical SOPs and training to the ops team are not specified in the contract.
#
# **26. Training and Awareness of End Users**
#
# - Status: Not Covered
# - Impact: Medium
# - Key Points: Not specified in the contract.
# - Remarks: The training and awareness of end users are not specified in the contract.
#
# **27. Intellectual Property and Source Code Ownership**
#
# - Status: Not Covered
# - Impact: High
# - Key Points: Not specified in the contract.
# - Remarks: The intellectual property and source code ownership are not specified in the contract.
#
# **28. Requirements / Support from Client**
#
# - Status: Not Covered
# - Impact: Medium
# - Key Points: Not specified in the contract.
# - Remarks: The requirements and support from the client are not specified in the contract.
#
# **29. Governance and Reporting**
#
# - Status: Partially Covered
# - Impact: Medium
# - Key Points:
#   • The laws of the People's Republic of China apply, with general international business practices applying if Chinese laws do not involve any matter in relation to the agreement.
#   • Disputes resolved through friendly negotiation. If dispute cannot be resolved through negotiation, submitted to China International Economic and Trade Commission for arbitration in Beijing.
# - Remarks: The governance and reporting are partially covered, but it may be beneficial to include more specific details about the governance and reporting.
#
# **30. Contract Exit Mechanism**
#
# - Status: Covered
# - Impact: Medium
# - Key Points:
#   • Prior to the expiration of the Term of Cooperation, this Agreement shall only be terminated upon occurrence of specific circumstances, including bankruptcy, force majeure, or failure to provide services for more than three consecutive years.
# - Remarks: The contract exit mechanism is clearly defined, but it may be beneficial to include more specific details about the exit process.
#
# **31. Payment Terms**
#
# - Status: Covered
# - Impact: Medium
# - Key Points:
#   • Party B shall have the right to charge a service fee (Service Fee) from Party A or its subsidiaries who have accepted Party B's Services.
# - Remarks: The payment terms are clearly defined, but it may be beneficial to include more specific details about the payment process.
#
# **32. Non-Functional Requirements**
#
# - Status: Not Covered
# - Impact: Medium
# - Key Points: Not specified in the contract.
# - Remarks: The non-functional requirements are not specified in the contract.
