# %%
from groq import Groq
from dotenv import load_dotenv
import os
import pdfplumber
import pandas as pd
import re

# %%
load_dotenv()
client = Groq(api_key=os.getenv("GROQ_API_KEY"))
print("Groq client ready")
# Out:
# Groq client ready

# %%
def call_llm(text):
    response = client.chat.completions.create(
        model="llama-3.1-8b-instant",  # current working model
        messages=[{"role": "user", "content": text}],
        temperature=0
    )
    return response.choices[0].message.content

# %%
def load_contract(path):
    ext = os.path.splitext(path)[1].lower()

    if ext == ".txt":
        with open(path, "r", encoding="utf-8") as f:
            return f.read()

    elif ext == ".pdf":
        text = []
        with pdfplumber.open(path) as pdf:
            for page in pdf.pages:
                page_text = page.extract_text()
                if page_text:
                    text.append(page_text)
        return "\n".join(text)

    else:
        raise ValueError("Unsupported file type")

# %%
def chunk_text(text, chunk_size=8000, overlap=500):
    chunks = []
    start = 0

    while start < len(text):
        end = start + chunk_size
        chunks.append(text[start:end])
        start = end - overlap

    return chunks

# %%
# CONTRACT_GUIDELINES = """

# 1. Scope
# - Detailed functional scope along with detailed Business Requirement Specifications (BRS) should be included in every contract.
# - Scope should be clear, unambiguous, and quantifiable to the extent possible.
# - For packaged solutions, desired functionality with modules and sub-modules should be mentioned.
# - For custom-built solutions, prioritized functional BRS should be included as part of annexures.
# - For services contracts, services should be clearly defined including asset coverage, service window, service levels, and locations.
# - A reasonable margin (e.g., 15%) for Change Requests (CRs) should be defined.

# 2. Duration
# - Deadline for project completion should be clearly mentioned.
# - AMC for a minimum of 3 years should accompany product implementation contracts.
# - A post go-live support period of at least 4 weeks should be included.

# 3. Deliverables
# - Expected deliverables should be clearly specified.
# - Timelines for deliverables should be defined.
# - Responsibility for delivery should be clearly mentioned.
# - Acceptance and performance criteria for deliverables should be specified.

# 4. Location / Geographical Scope
# - Locations covered under the contract should be clearly defined.
# - Level of coverage across locations should be specified.

# 5. Timelines
# - A high-level project plan with timelines and responsibilities should be included.

# 6. Technical Architecture
# - Proposed technical architecture should be mentioned for technical implementations.
# - Architecture should cover front end, servers, platform, databases, and middleware.

# 7. Scope Assumptions and Exclusions
# - Any assumptions or exclusions should be clearly specified.

# 8. Service Level Agreements (SLAs)
# - Expected service levels for each service should be defined.
# - SLA monitoring frequency and mechanism should be specified.
# - Bonus and penalty criteria related to SLAs should be mentioned.

# 9. Project Structure, Roles and Responsibilities
# - Ownership of deliverables should be clearly defined.
# - Roles and responsibilities of vendor, business, and IT stakeholders should be documented.

# 10. Handling Changes to Baseline
# - A clearly defined change management process should be included.

# 11. Commercial Model
# - Commercial model (fixed price, T&M, hybrid) should be specified.
# - Mechanism for handling scope changes should be predefined.
# - Man-month rates should be defined where applicable.

# 12. Billing Model
# - Billing milestones or billing cycles should be clearly defined.
# - Payment cycles should align with milestones and progress.
# - Payments should be linked to acceptance of deliverables where possible.

# 13. Overhead Expenses
# - Mechanism for managing vendor out-of-pocket expenses (OPEs) should be specified.
# - Applicable limits should be mentioned.

# 14. Incentives / Disincentives
# - Bonus and penalty criteria should be specified.
# - Penalties should be capped at mutually agreed levels (e.g., 10%).

# 15. Procurement and Licensing Model
# - Responsibility for procurement of hardware and software licenses should be defined.

# 16. Operations Model
# - Service delivery model should be defined for ongoing operations.

# 17. Acceptance and Performance Criteria
# - Acceptance criteria and process should be clearly specified.
# - Acceptance should be linked to vendor payments.

# 18. Performance Criteria
# - Criteria for measuring project performance should be defined.

# 19. Discretionary Hours / Development Effort
# - Discretionary or buffer hours should be clearly defined.

# 20. Minimum Skill Set
# - Expected skill sets for vendor resources should be defined.

# 21. Resource Deployment Model
# - Onsite deployment should be preferred.
# - Minimum onsite resource requirements should be specified where remote work is used.

# 22. Subcontracting / Consortium Guidelines
# - Subcontracting should be avoided or limited (preferably less than 30%).

# 23. Handholding Support (Post Go-Live)
# - Post go-live handholding support period should be specified.
# - Handholding support should be at least one month and separate from AMC.

# 24. Ongoing Operations Support
# - Functional and technical support model should be defined.

# 25. Technical SOPs and Training to Operations Team
# - High-level transition and training plan should be included.
# - Number of trainings and training man-days should be specified.

# 26. Training and Awareness of End Users
# - High-level end-user training plan should be included.
# - Training coverage and effort should be specified.

# 27. Intellectual Property and Source Code Ownership
# - Ownership of IP and source code should be clearly mentioned for custom-built solutions.

# 28. Resource Replacement / Transitioning Guidelines
# - Vendor should avoid replacing project resources.
# - If required, a clear transition and change management plan should be defined.

# 29. Requirements / Support from Client
# - Vendor should specify required client support such as:
#   - Hardware procurement
#   - License procurement
#   - Dedicated project manager
#   - Logistics and operational support

# 30. Governance (Risk, Issue, Change and Quality Management) and Reporting
# - Governance and reporting should follow PMO guidelines.

# 31. Organization Change Management and Communication
# - Vendor should support organization change management as per PMO guidelines.

# 32. Contract Exit Mechanism
# - Contract exit terms and conditions should be clearly defined.
# """

# %%
# def summarize_chunk(chunk):
#     prompt = f"""
# You are a contract intelligence assistant.

# Task:
# Summarize the following contract text STRICTLY in the context of the guidelines.

# Rules:
# - Only extract information relevant to the guidelines
# - Map clauses to guideline-related topics where possible
# - If something is unclear or incomplete, mention it explicitly
# - Do NOT analyze risk
# - Do NOT provide opinions
# - Keep output concise and factual

# Contract Text:
# {chunk}

# Output:
# Concise factual notes aligned to the guidelines.
# """
#     return call_llm(prompt)

# %%
def summarize_chunk(chunk):
    prompt = f"""
Summarize the following contract text into concise factual notes.
- Extract clauses, obligations, payments, timelines, responsibilities
- Do NOT analyze
- Do NOT format
- Keep it short and factual

Text:
{chunk}
"""
    return call_llm(prompt)

# %%
def batch_reduce(summaries, batch_size=5):
    reduced = []

    for i in range(0, len(summaries), batch_size):
        batch = summaries[i:i+batch_size]
        batch_text = "\n\n".join(batch)

        prompt = f"""
Combine the following notes into a concise unified summary.
Do not lose important details.

Notes:
{batch_text}
"""
        reduced.append(call_llm(prompt))

    return reduced

# %%
REVIEW_SECTIONS = [
    "Scope",
    "Duration",
    "Deliverables",
    "Location / Geographical Scope",
    "Timelines",
    "Technical Architecture",
    "Scope Assumptions and Exclusions",
    "Service Level Agreements (SLAs)",
    "Project Structure, Roles and Responsibilities",
    "Handling Changes to Baseline",
    "Commercial Model",
    "Billing Model",
    "Overhead Expenses",
    "Incentives / Disincentives",
    "Procurement and Licensing Model",
    "Operations Model",
    "Acceptance Criteria",
    "Performance Criteria",
    "Discretionary Hours / Development Effort",
    "Minimum Skill Set",
    "Resource Deployment / Replacement Guidelines",
    "Subcontracting / Consortium Guidelines",
    "Handholding Support (Post Go-Live)",
    "Ongoing Operations Support",
    "Technical SOPs and Training to Ops Team",
    "Training and Awareness of End Users",
    "Intellectual Property and Source Code Ownership",
    "Requirements / Support from Client",
    "Governance and Reporting",
    "Contract Exit Mechanism",
    "Payment Terms",
    "Non-Functional Requirements"
]

# %%
ONE_SHOT_EXAMPLE = """
Example Contract Review (Reference Style)

1. Functional Scope

Status: Covered
Impact: Low

Key Points:
- Functional scope is defined in Section 2 of the contract.
- Detailed scope of work and out-of-scope areas are captured in Exhibits A–D.

Remarks:
No margin provided for Change Requests, as mentioned in Section 2.11.


2. Deliverables

Status: Partially Covered
Impact: Medium

Key Points:
- Deliverables are clearly mentioned in Exhibit D (Section 2.3).
- Acceptance criteria for documents are not defined in the contract.
- Training and user manuals to be provided by the vendor/customer are not clearly mentioned.

Remarks:
Deliverables and templates may need to be finalized during the Discovery phase.


3. Location / Geographical Scope

Status: Covered
Impact: Low

Key Points:
- Work location for the vendor’s team is clearly mentioned in Exhibit D (Section 2.14).


4. Technical Architecture

Status: Not Covered
Impact: Medium

Key Points:
- Technical architecture details are not mentioned anywhere in the contract.

Remarks:
Technical architecture may be defined and finalized during the Discovery phase.


5. Service Level Agreements (SLA)

Status: Covered
Impact: Low

Key Points:
- Service levels and penalty clauses are clearly defined in Exhibits A and B (Section 3.2).


6. Intellectual Property and Source Code Ownership

Status: Covered
Impact: Low

Key Points:
- Ownership of intellectual property and source code is clearly mentioned in Section 11.


7. Non-Functional Requirements

Status: Not Covered
Impact: High

Key Points:
- Non-functional requirements such as performance, scalability, or security requirements are not specified in the contract.
"""

# %%
def generate_contract_review(notes):
    sections = "\n".join(
        f"{i+1}. {section}"
        for i, section in enumerate(REVIEW_SECTIONS)
    )

    prompt =  f"""
You are a contract review assistant performing a structured contract review
following internal PMO contract review style.

Your task is to analyze the contract notes and generate a structured review
for each aspect listed below.

Rules:
- Follow the exact section order provided.
- For EACH section include:

Status: Covered / Partially Covered / Not Covered / NA  
Impact: Low / Medium / High / NA  
Key Points: bullet points explaining the clause, clarity, completeness, and any gaps  
Remarks: additional observations if applicable

Guidelines for analysis:
- Key Points should summarize the relevant clause content and provide analytical observations.
- Mention the contract section number, heading, or exhibit where information is found when available.
- If a section number is not visible, describe the clause without inventing references.
- If certain details are missing or unclear, explain the gap rather than only stating that it is missing.
- Focus on meaningful contract review insights similar to internal consulting contract reviews.
- Do NOT provide legal advice.

Use the example below ONLY to understand formatting and reasoning style.
Do NOT copy or paraphrase the example content.

Example Review:
{ONE_SHOT_EXAMPLE}

Sections to Review:
{sections}

Contract Notes:
{notes}

Generate the contract review using the same structure and tone as the example.
Ensure each section includes Status, Impact, Key Points, and Remarks (if applicable).
"""
    return call_llm(prompt)

# %%
# 1. Load contract
contract_text = load_contract("contract.pdf")
print("Contract loaded:", len(contract_text), "characters")
# Out:
# Contract loaded: 17691 characters

# %%
# 2. Chunk
chunks = chunk_text(contract_text)
print("Chunks:", len(chunks))
# Out:
# Chunks: 3

# %%
# 3. FIRST PASS (compress chunks)
chunk_summaries = [summarize_chunk(chunk) for chunk in chunks]
print("Chunk summaries done")
# Out:
# Chunk summaries done

# %%
# 4. REDUCTION PASSES
level_2 = batch_reduce(chunk_summaries)
level_3 = batch_reduce(level_2)

# %%
combined_notes = "\n\n".join(level_3)
print("Final notes size:", len(combined_notes))
# Out:
# Final notes size: 2197

# %%
# 5. FINAL REVIEW
final_review = generate_contract_review(combined_notes)

# %%
# CHECKLIST_COLUMNS = [
#     "Clause Name",
#     "Clause Text",
#     "Risk Level",
#     "Issue Identified",
#     "Recommendation",
#     "Comments"
# ]

# %%
import re
import pandas as pd
import os

rows = []

# Split sections based on numbering like "1. Functional Scope"
sections = re.split(r"\n\s*(\d+\.\s+[^\n]+)", final_review)

for i in range(1, len(sections), 2):
    header = sections[i].strip()
    body = sections[i + 1]

    # Extract clause number and title
    clause_number, clause_title = header.split(".", 1)
    clause_number = clause_number.strip()
    clause_title = clause_title.strip()

    # Extract fields
    status_match = re.search(r"Status:\s*(.+)", body)
    impact_match = re.search(r"Impact:\s*(.+)", body)
    remarks_match = re.search(r"Remarks:\s*(.+)", body, re.DOTALL)

    # Extract key points block
    key_points_match = re.search(r"Key Points:(.*?)(Remarks:|$)", body, re.DOTALL)

    key_points = ""
    if key_points_match:
        key_points = "\n".join(
            line.replace("-", "").replace("•", "").strip()
            for line in key_points_match.group(1).splitlines()
            if "-" in line or "•" in line
        )

    rows.append({
        "Clause Number": clause_number,
        "Clause Title": clause_title,
        "Status": status_match.group(1).strip() if status_match else "",
        "Impact": impact_match.group(1).strip() if impact_match else "",
        "Key Points": key_points,
        "Remarks": remarks_match.group(1).strip() if remarks_match else ""
    })

print("Number of rows:", len(rows))
print(rows[:3])

# Save CSV
df = pd.DataFrame(rows)

os.makedirs("outputs", exist_ok=True)

df.to_csv("outputs/final_contract_review_v6.csv", index=False)

print("CSV saved successfully")
# Out:
# Number of rows: 17
# [{'Clause Number': '2', 'Clause Title': 'Duration', 'Status': 'Covered', 'Impact': 'Low', 'Key Points': "The term of cooperation commences from the execution date and ends on the expiration date of the operation term of Party B (Section 4).\nThe duration of the cooperation is not explicitly mentioned, but it is implied to be until the expiration date of Party B's operation term.", 'Remarks': 'The duration of the cooperation may need to be clarified and agreed upon by both parties to avoid any disputes.'}, {'Clause Number': '3', 'Clause Title': 'Deliverables', 'Status': 'Partially Covered', 'Impact': 'Medium', 'Key Points': 'The deliverables of the cooperation are not explicitly mentioned in the contract.\nHowever, the scope of services includes research, development, production, and maintenance of relevant technology, internet platforms, and tour products (Section 1.1).\nThe deliverables may include the development of technology, internet platforms, and tour products, but this is not explicitly stated.', 'Remarks': 'The deliverables of the cooperation may need to be clarified and detailed during the cooperation period to ensure that both parties understand their responsibilities.'}, {'Clause Number': '4', 'Clause Title': 'Location / Geographical Scope', 'Status': 'Covered', 'Impact': 'Low', 'Key Points': "The location of the cooperation is not explicitly mentioned in the contract.\nHowever, the scope of services includes research, development, production, and maintenance of relevant technology, internet platforms, and tour products (Section 1.1).\nThe geographical scope of the cooperation is implied to be limited to the People's Republic of China, as the governing law is specified as the laws of the People's Republic of China (Section 7).", 'Remarks': 'The location and geographical scope of the cooperation may need to be clarified and agreed upon by both parties to avoid any disputes.'}]
# CSV saved successfully

# %%
print(final_review)
# Out:
# 1. Scope
#
# Status: Partially Covered
# Impact: Medium
#
# Key Points:
# - The scope of cooperation is defined in Section 1.1, where Party B provides business consultancy and technical services to Party A and its subsidiaries.
# - The scope of services includes research, development, production, and maintenance of relevant technology, internet platforms, and tour products (Section 1.1).
# - However, the scope of services does not explicitly mention the specific areas of technology, internet platforms, or tour products.
# - The scope of services does not include any out-of-scope areas or exclusions.
#
# Remarks:
# The scope of services may need to be clarified and detailed during the cooperation period to avoid any misunderstandings.
#
#
# 2. Duration
#
# Status: Covered
# Impact: Low
#
# Key Points:
# - The term of cooperation commences from the execution date and ends on the expiration date of the operation term of Party B (Section 4).
# - The duration of the cooperation is not explicitly mentioned, but it is implied to be until the expiration date of Party B's operation term.
#
# Remarks:
# The duration of the cooperation may need to be clarified and agreed upon by both parties to avoid any disputes.
#
#
# 3. Deliverables
#
# Status: Partially Covered
# Impact: Medium
#
# Key Points:
# - The deliverables of the cooperation are not explicitly mentioned in the contract.
# - However, the scope of services includes research, development, production, and maintenance of relevant technology, internet platforms, and tour products (Section 1.1).
# - The deliverables may include the development of technology, internet platforms, and tour products, but this is not explicitly stated.
#
# Remarks:
# The deliverables of the cooperation may need to be clarified and detailed during the cooperation period to ensure that both parties understand their responsibilities.
#
#
# 4. Location / Geographical Scope
#
# Status: Covered
# Impact: Low
#
# Key Points:
# - The location of the cooperation is not explicitly mentioned in the contract.
# - However, the scope of services includes research, development, production, and maintenance of relevant technology, internet platforms, and tour products (Section 1.1).
# - The geographical scope of the cooperation is implied to be limited to the People's Republic of China, as the governing law is specified as the laws of the People's Republic of China (Section 7).
#
# Remarks:
# The location and geographical scope of the cooperation may need to be clarified and agreed upon by both parties to avoid any disputes.
#
#
# 5. Timelines
#
# Status: Not Covered
# Impact: Medium
#
# Key Points:
# - The timelines for the cooperation are not explicitly mentioned in the contract.
# - However, the term of cooperation commences from the execution date and ends on the expiration date of the operation term of Party B (Section 4).
# - The timelines for the cooperation may need to be clarified and agreed upon by both parties to ensure that both parties understand their responsibilities.
#
# Remarks:
# The timelines for the cooperation may need to be clarified and detailed during the cooperation period to avoid any delays or disputes.
#
#
# 6. Technical Architecture
#
# Status: Not Covered
# Impact: Medium
#
# Key Points:
# - The technical architecture of the cooperation is not explicitly mentioned in the contract.
# - However, the scope of services includes research, development, production, and maintenance of relevant technology, internet platforms, and tour products (Section 1.1).
# - The technical architecture may need to be clarified and detailed during the cooperation period to ensure that both parties understand their responsibilities.
#
# Remarks:
# The technical architecture of the cooperation may need to be clarified and agreed upon by both parties to avoid any disputes.
#
#
# 7. Scope Assumptions and Exclusions
#
# Status: Partially Covered
# Impact: Medium
#
# Key Points:
# - The scope of services includes research, development, production, and maintenance of relevant technology, internet platforms, and tour products (Section 1.1).
# - However, the scope of services does not explicitly mention any assumptions or exclusions.
# - The scope of services does not include any out-of-scope areas or exclusions.
#
# Remarks:
# The scope of services may need to be clarified and detailed during the cooperation period to avoid any misunderstandings.
#
#
# 8. Service Level Agreements (SLAs)
#
# Status: Not Covered
# Impact: Medium
#
# Key Points:
# - The service level agreements (SLAs) for the cooperation are not explicitly mentioned in the contract.
# - However, the scope of services includes research, development, production, and maintenance of relevant technology, internet platforms, and tour products (Section 1.1).
# - The SLAs may need to be clarified and detailed during the cooperation period to ensure that both parties understand their responsibilities.
#
# Remarks:
# The SLAs for the cooperation may need to be clarified and agreed upon by both parties to avoid any disputes.
#
#
# 9. Project Structure, Roles and Responsibilities
#
# Status: Partially Covered
# Impact: Medium
#
# Key Points:
# - The project structure and roles and responsibilities are not explicitly mentioned in the contract.
# - However, the scope of services includes research, development, production, and maintenance of relevant technology, internet platforms, and tour products (Section 1.1).
# - The project structure and roles and responsibilities may need to be clarified and detailed during the cooperation period to ensure that both parties understand their responsibilities.
#
# Remarks:
# The project structure and roles and responsibilities of the cooperation may need to be clarified and agreed upon by both parties to avoid any disputes.
#
#
# 10. Handling Changes to Baseline
#
# Status: Not Covered
# Impact: Medium
#
# Key Points:
# - The process for handling changes to the baseline is not explicitly mentioned in the contract.
# - However, the agreement can be terminated upon occurrence of certain circumstances, including Party B's termination in advance, bankruptcy, or failure to provide services for more than three consecutive years due to force majeure (Section 5).
# - The process for handling changes to the baseline may need to be clarified and detailed during the cooperation period to ensure that both parties understand their responsibilities.
#
# Remarks:
# The process for handling changes to the baseline of the cooperation may need to be clarified and agreed upon by both parties to avoid any disputes.
#
#
# 11. Commercial Model
#
# Status: Covered
# Impact: Low
#
# Key Points:
# - The commercial model for the cooperation is based on a service fee (Service Fee) charged by Party B from Party A or its subsidiaries who have accepted Party B's Services (Section 3).
# - The Service Fee is equal to the amount of profits gained by Party A or its subsidiaries.
#
# Remarks:
# The commercial model for the cooperation may need to be clarified and detailed during the cooperation period to ensure that both parties understand their responsibilities.
#
#
# 12. Billing Model
#
# Status: Covered
# Impact: Low
#
# Key Points:
# - The billing model for the cooperation is not explicitly mentioned in the contract.
# - However, the commercial model is based on a service fee (Service Fee) charged by Party B from Party A or its subsidiaries who have accepted Party B's Services (Section 3).
# - The Service Fee is equal to the amount of profits gained by Party A or its subsidiaries.
#
# Remarks:
# The billing model for the cooperation may need to be clarified and detailed during the cooperation period to ensure that both parties understand their responsibilities.
#
#
# 13. Overhead Expenses
#
# Status: Not Covered
# Impact: Medium
#
# Key Points:
# - The overhead expenses for the cooperation are not explicitly mentioned in the contract.
# - However, the commercial model is based on a service fee (Service Fee) charged by Party B from Party A or its subsidiaries who have accepted Party B's Services (Section 3).
# - The Service Fee is equal to the amount of profits gained by Party A or its subsidiaries.
#
# Remarks:
# The overhead expenses for the cooperation may need to be clarified and detailed during the cooperation period to ensure that both parties understand their responsibilities.
#
#
# 14. Incentives / Disincentives
#
# Status: Not Covered
# Impact: Medium
#
# Key Points:
# - The incentives and disincentives for the cooperation are not explicitly mentioned in the contract.
# - However, the commercial model is based on a service fee (Service Fee) charged by Party B from Party A or its subsidiaries who have accepted Party B's Services (Section 3).
# - The Service Fee is equal to the amount of profits gained by Party A or its subsidiaries.
#
# Remarks:
# The incentives and disincentives for the cooperation may need to be clarified and detailed during the cooperation period to ensure that both parties understand their responsibilities.
#
#
# 15. Procurement and Licensing Model
#
# Status: Not Covered
# Impact: Medium
#
# Key Points:
# - The procurement and licensing model for the cooperation is not explicitly mentioned in the contract.
# - However, the scope of services includes research, development, production, and maintenance of relevant technology, internet platforms, and tour products (Section 1.1).
# - The procurement and licensing model may need to be clarified and detailed during the cooperation period to ensure that both parties understand their responsibilities.
#
# Remarks:
# The procurement and licensing model for the cooperation may need to be clarified and agreed upon by both parties to avoid any disputes.
#
#
# 16. Operations Model
#
# Status: Not Covered
# Impact: Medium
#
# Key Points:
# - The operations model for the cooperation is not explicitly mentioned in the contract.
# - However, the scope of services includes research, development, production, and maintenance of relevant technology, internet platforms, and tour products (Section 1.1).
# - The operations model may need to be clarified and detailed during the cooperation period to ensure that both parties understand their responsibilities.
#
# Remarks:
# The operations model for the cooperation may need to be clarified and agreed upon by both parties to avoid any disputes.
#
#
# 17. Acceptance Criteria
#
# Status: Not Covered
# Impact: Medium
#
# Key Points:
# - The acceptance criteria for the cooperation are not explicitly mentioned in the contract.
# - However, the scope of services includes research, development, production, and maintenance of relevant technology, internet platforms, and tour products (Section 1.1).
# - The acceptance criteria may need to be clarified and detailed during the cooperation period to ensure that both parties understand their responsibilities.
#
# Remarks:
# The acceptance criteria for the cooperation may need to be clarified and agreed upon by both parties to avoid any disputes.
#
#
# 18. Performance Criteria
#
# Status: Not Covered
# Impact: Medium
#
# Key
